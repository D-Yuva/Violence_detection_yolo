# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 911.6/911.6 kB 40.6 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.65 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 31.1/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd /content/drive/MyDrive/Violence Detection/Violence.v1i.yolov8
# Out:
# /content/drive/MyDrive/Violence Detection/Violence.v1i.yolov8

# %%
# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=25 imgsz=416 plots=True
# Out:
# Ultralytics 8.3.65 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename='/content/drive/MyDrive/Violence Detection/Violence.v1i.yolov8/runs/detect/train3/results.png', width=600)

# %%
display(Image(filename='/content/drive/MyDrive/Violence Detection/Violence.v1i.yolov8/runs/detect/train3/confusion_matrix.png', width=600) , Image(filename='/content/drive/MyDrive/Violence Detection/Violence.v1i.yolov8/runs/detect/train3/confusion_matrix.png', width=600))

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/ViolenceDetection/Violence.v1i.yolov8/runs/detect/train3/weights/best.pt data=data.yaml
# Out:
# Ultralytics 8.3.65 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/drive/MyDrive/ViolenceDetection/Violence.v1i.yolov8/valid/labels... 575 images, 10 backgrounds, 0 corrupt: 100% 585/585 [00:06<00:00, 90.14it/s]
# val: New cache created: /content/drive/MyDrive/ViolenceDetection/Violence.v1i.yolov8/valid/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 37/37 [00:08<00:00,  4.13it/s]
#                    all        585        978       0.85       0.83      0.891      0.583
#            NonViolence        220        430      0.814      0.813      0.866      0.558
#               Violence        529        548      0.886      0.847      0.916      0.608
# Speed: 0.7ms preprocess, 4.2ms inference, 0.0ms loss, 3.4ms postprocess per image
# Results saved to runs/detect/val2
# ...

# %%
  display(Image(filename='/content/drive/MyDrive/ViolenceDetection/Violence.v1i.yolov8/runs/detect/val2/confusion_matrix.png', width=600))

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/ViolenceDetection/Violence.v1i.yolov8/runs/detect/train3/weights/best.pt conf=0.25 source=/content/drive/MyDrive/ViolenceDetection/Violence.v1i.yolov8/test/images
# Out:
# Ultralytics 8.3.65 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/290 /content/drive/MyDrive/ViolenceDetection/Violence.v1i.yolov8/test/images/NV_118_F44_jpg.rf.53f9248d0de24bb3b608bdc4cce78bd4.jpg: 416x416 1 NonViolence, 10.4ms
# image 2/290 /content/drive/MyDrive/ViolenceDetection/Violence.v1i.yolov8/test/images/NV_118_F72_jpg.rf.8e0cf97451cba97e942718e6b5021bb9.jpg: 416x416 1 NonViolence, 10.4ms
# image 3/290 /content/drive/MyDrive/ViolenceDetection/Violence.v1i.yolov8/test/images/NV_137_F100_jpg.rf.b9ffa3cd0ec141ba4a5b1e23203f6301.jpg: 416x416 1 NonViolence, 23.4ms
# image 4/290 /content/drive/MyDrive/ViolenceDetection/Violence.v1i.yolov8/test/images/NV_140_F24_jpg.rf.67bf6a0891129ef0fc5bf8a922da32a8.jpg: 416x416 (no detections), 13.8ms
# ...
